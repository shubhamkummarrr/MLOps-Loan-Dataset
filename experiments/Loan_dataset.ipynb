# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import kagglehub
import os

path = kagglehub.dataset_download("taweilo/loan-approval-classification-data")

data = os.path.join(path,"loan_data.csv")

# %%
path
# Out:
# 'C:\\Users\\tally\\.cache\\kagglehub\\datasets\\taweilo\\loan-approval-classification-data\\versions\\1'

# %%
df = pd.read_csv(data)

# %%
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('_________________________________________________________________')
# Out:
# person_age
# 23.0     5254
# 24.0     5138
# 25.0     4507
# 22.0     4236
# 26.0     3659
# 27.0     3095
# 28.0     2728
# 29.0     2455
# 30.0     2021
# 31.0     1645
# 32.0     1403
# 21.0     1289
# 33.0     1240
# 34.0      980
# 35.0      847
# 36.0      740
# 37.0      666
# 38.0      503
# 39.0      389
# 40.0      349
# 41.0      303
# 42.0      247
# 43.0      215
# 44.0      177
# 45.0      135
# 46.0      114
# 47.0      112
# 48.0       93
# 49.0       59
# 50.0       56
# 51.0       46
# 52.0       42
# 53.0       35
# 54.0       24
# 55.0       24
# 58.0       20
# 56.0       20
# 57.0       17
# 20.0       17
# 60.0       16
# 61.0       12
# 66.0       11
# 65.0       10
# 70.0        7
# 64.0        7
# 62.0        7
# 59.0        6
# 69.0        5
# 144.0       3
# 73.0        3
# 63.0        3
# 123.0       2
# 78.0        1
# 94.0        1
# 80.0        1
# 84.0        1
# 76.0        1
# 67.0        1
# 116.0       1
# 109.0       1
# ...

# %%
for i in df.columns:
    print(df[i].unique())
    print('_________________________________________________________________')
# Out:
# [ 22.  21.  25.  23.  24.  26. 144. 123.  20.  32.  34.  29.  33.  28.
#   35.  31.  27.  30.  36.  40.  50.  45.  37.  39.  44.  43.  41.  46.
#   38.  47.  42.  48.  49.  58.  65.  51.  53.  66.  61.  54.  57.  59.
#   62.  60.  55.  52.  64.  70.  78.  69.  56.  73.  63.  94.  80.  84.
#   76.  67. 116. 109.]
# _________________________________________________________________
# ['female' 'male']
# _________________________________________________________________
# ['Master' 'High School' 'Bachelor' 'Associate' 'Doctorate']
# _________________________________________________________________
# [71948. 12282. 12438. ... 31924. 56942. 33164.]
# _________________________________________________________________
# [  0   3   1   5   4   2   7   6 125   8 121 101 100  12  10   9  14  13
#   11  15  16  17  19  28  25  18  24  22  20  23  21  31  26  27  29  32
#   30 124  40  43  33  44  34  42  37  45  36  41  47  38  39  35  57  46
#   49  48  50  76  62  61  58  93  85]
# ...

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df.groupby('person_gender')['loan_status'].count()
# Out:
# person_gender
# female    20159
# male      24841
# Name: loan_status, dtype: int64

# %%
# cols = ['person_gender', 'person_education', 'person_home_ownership', 'loan_intent', 'previous_loan_defaults_on_file']

# for i in cols:
#     plt.figure(figsize=(8, 4))  # Optional: thoda space and clarity
#     sns.histplot(df[i])
#     plt.title(f'Distribution of {i}')
#     plt.xticks(rotation=45)  # Better readability if too many categories
#     plt.tight_layout()
#     plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# cols = ['person_gender', 'person_education', 'person_home_ownership', 'loan_intent', 'previous_loan_defaults_on_file']

# for i in cols:
#     plt.figure(figsize=(10, 5))
#     sns.boxplot(x=df[i], y=df['loan_amnt'], hue=df['loan_status'])
#     plt.title(f'Loan Amount vs {i} (by Loan Status)')
#     plt.xticks(rotation=45)
#     plt.tight_layout()
#     plt.show()

# %%
df[['person_age','person_income','loan_amnt','loan_int_rate','loan_percent_income','cb_person_cred_hist_length','credit_score']]
# Out:
#        person_age  person_income  loan_amnt  loan_int_rate  \
# 0            22.0        71948.0    35000.0          16.02
# 1            21.0        12282.0     1000.0          11.14
# 2            25.0        12438.0     5500.0          12.87
# 3            23.0        79753.0    35000.0          15.23
# 4            24.0        66135.0    35000.0          14.27
# ...           ...            ...        ...            ...
# 44995        27.0        47971.0    15000.0          15.66
# 44996        37.0        65800.0     9000.0          14.07
# 44997        33.0        56942.0     2771.0          10.02
# 44998        29.0        33164.0    12000.0          13.23
# 44999        24.0        51609.0     6665.0          17.05
#
#        loan_percent_income  cb_person_cred_hist_length  credit_score
# 0                     0.49                         3.0           561
# 1                     0.08                         2.0           504
# ...

# %%
cols2 = ['person_age','person_income','loan_amnt','loan_int_rate','loan_percent_income','cb_person_cred_hist_length','credit_score']

for i in cols2:
    sns.scatterplot(df[i])
    plt.title(f'Distribution of {i}')
    plt.xticks(rotation=45)  # Better readability if too many categories
    plt.tight_layout()
    plt.show()

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %% [markdown]
# # **Person_Age

# %%
df["person_age"] = df["person_age"].astype(int)

# %%
df["person_age"].describe()
# Out:
# count    45000.000000
# mean        27.764178
# std          6.045108
# min         20.000000
# 25%         24.000000
# 50%         26.000000
# 75%         30.000000
# max        144.000000
# Name: person_age, dtype: float64

# %%
sns.scatterplot(df["person_age"])
# Out:
# <Axes: ylabel='person_age'>

# %%
df = df[df['person_age'] <= 100]

# %%
df["person_age"]
# Out:
# 0        22
# 1        21
# 2        25
# 3        23
# 4        24
#          ..
# 44995    27
# 44996    37
# 44997    33
# 44998    29
# 44999    24
# Name: person_age, Length: 44993, dtype: int32

# %%
df['person_age'].unique()
# Out:
# array([22, 21, 25, 23, 24, 26, 20, 32, 34, 29, 33, 28, 35, 31, 27, 30, 36,
#        40, 50, 45, 37, 39, 44, 43, 41, 46, 38, 47, 42, 48, 49, 58, 65, 51,
#        53, 66, 61, 54, 57, 59, 62, 60, 55, 52, 64, 70, 78, 69, 56, 73, 63,
#        94, 80, 84, 76, 67])

# %% [markdown]
# # **Person_Gender

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master        71948.0
# 1              21        female      High School        12282.0
# 2              25        female      High School        12438.0
# 3              23        female         Bachelor        79753.0
# 4              24          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995          27          male        Associate        47971.0
# 44996          37        female        Associate        65800.0
# 44997          33          male        Associate        56942.0
# 44998          29          male         Bachelor        33164.0
# 44999          24          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df['person_gender'].value_counts()
# Out:
# person_gender
# male      24836
# female    20157
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['gender'] = le.fit_transform(df['person_gender'])
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\3689954872.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = le.fit_transform(df['person_gender'])

# %%
df['person_gender'].value_counts()
# Out:
# person_gender
# male      24836
# female    20157
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# 1    24836
# 0    20157
# Name: count, dtype: int64

# %%
# male
df[df['person_gender'] == 'male']['loan_status'].value_counts(normalize=True) * 100
# Out:
# loan_status
# 0    77.794331
# 1    22.205669
# Name: proportion, dtype: float64

# %%
# female
df[df['person_gender'] == 'female']['loan_status'].value_counts(normalize=True) * 100
# Out:
# loan_status
# 0    77.749665
# 1    22.250335
# Name: proportion, dtype: float64

# %% [markdown]
# # **person_education

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master        71948.0
# 1              21        female      High School        12282.0
# 2              25        female      High School        12438.0
# 3              23        female         Bachelor        79753.0
# 4              24          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995          27          male        Associate        47971.0
# 44996          37        female        Associate        65800.0
# 44997          33          male        Associate        56942.0
# 44998          29          male         Bachelor        33164.0
# 44999          24          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
for i in df['person_education'].unique():
    print(i)
    print(df[df['person_education'] == i]['loan_status'].value_counts(normalize=True) * 100)
    print(df[df['person_education'] == i]['loan_status'].value_counts())
    print('-------------------------------------')
# Out:
# Master
# loan_status
# 0    78.237822
# 1    21.762178
# Name: proportion, dtype: float64
# loan_status
# 0    5461
# 1    1519
# Name: count, dtype: int64
# -------------------------------------
# High School
# loan_status
# 0    77.685881
# 1    22.314119
# Name: proportion, dtype: float64
# loan_status
# 0    9299
# 1    2671
# Name: count, dtype: int64
# -------------------------------------
# Bachelor
# loan_status
# 0    77.470887
# 1    22.529113
# Name: proportion, dtype: float64
# loan_status
# 0    10378
# 1     3018
# Name: count, dtype: int64
# -------------------------------------
# Associate
# loan_status
# 0    77.96441
# 1    22.03559
# Name: proportion, dtype: float64
# loan_status
# 0    9376
# 1    2650
# Name: count, dtype: int64
# -------------------------------------
# Doctorate
# loan_status
# 0    77.133655
# 1    22.866345
# Name: proportion, dtype: float64
# loan_status
# 0    479
# 1    142
# Name: count, dtype: int64
# ...

# %%
df['person_education'].value_counts(normalize=True)
# Out:
# person_education
# Bachelor       0.297735
# Associate      0.267286
# High School    0.266041
# Master         0.155135
# Doctorate      0.013802
# Name: proportion, dtype: float64

# %%
df['Education'] = le.fit_transform(df['person_education'])
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\869474805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Education'] = le.fit_transform(df['person_education'])

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master        71948.0
# 1              21        female      High School        12282.0
# 2              25        female      High School        12438.0
# 3              23        female         Bachelor        79753.0
# 4              24          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995          27          male        Associate        47971.0
# 44996          37        female        Associate        65800.0
# 44997          33          male        Associate        56942.0
# 44998          29          male         Bachelor        33164.0
# 44999          24          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %% [markdown]
# # **person_income

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master        71948.0
# 1              21        female      High School        12282.0
# 2              25        female      High School        12438.0
# 3              23        female         Bachelor        79753.0
# 4              24          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995          27          male        Associate        47971.0
# 44996          37        female        Associate        65800.0
# 44997          33          male        Associate        56942.0
# 44998          29          male         Bachelor        33164.0
# 44999          24          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df['person_income'] = df['person_income'].astype(int)
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\2881208596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['person_income'] = df['person_income'].astype(int)

# %%
df['person_income'].describe()
# Out:
# count    4.499300e+04
# mean     7.990845e+04
# std      6.332213e+04
# min      8.000000e+03
# 25%      4.719500e+04
# 50%      6.704600e+04
# 75%      9.577800e+04
# max      2.448661e+06
# Name: person_income, dtype: float64

# %%
sns.scatterplot(df['person_income'])
# Out:
# <Axes: ylabel='person_income'>

# %%
# removed outlier
df = df[df['person_income'] < 1500000]

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71948
# 1              21        female      High School          12282
# 2              25        female      High School          12438
# 3              23        female         Bachelor          79753
# 4              24          male           Master          66135
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47971
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56942
# 44998          29          male         Bachelor          33164
# 44999          24          male      High School          51609
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df['person_income'].unique().shape
# Out:
# (33974,)

# %%
df['person_income'] = df['person_income'].apply(lambda x:(x//100)*100)
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\454350926.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['person_income'] = df['person_income'].apply(lambda x:(x//100)*100)

# %%
df['person_income'].unique().shape
# Out:
# (2352,)

# %% [markdown]
# # **person_emp_exp

# %%
# no need to modify
df['person_emp_exp'].unique()
# Out:
# array([ 0,  3,  1,  5,  4,  2,  7,  6,  8, 12, 10,  9, 14, 13, 11, 15, 16,
#        17, 19, 28, 25, 18, 24, 22, 20, 23, 21, 31, 26, 27, 29, 32, 30, 40,
#        43, 33, 44, 34, 42, 37, 45, 36, 41, 47, 38, 39, 35, 57, 46, 49, 48,
#        50, 76, 62, 61, 58], dtype=int64)

# %%
for i in df['person_emp_exp'].unique():
    print('  #',i,'Experience')
    print(df[df['person_emp_exp'] == i]['loan_status'].value_counts())
    print('-------------------------------------')
# Out:
#   # 0 Experience
# loan_status
# 0    7243
# 1    2323
# Name: count, dtype: int64
# -------------------------------------
#   # 3 Experience
# loan_status
# 0    3022
# 1     868
# Name: count, dtype: int64
# -------------------------------------
#   # 1 Experience
# loan_status
# 0    3136
# 1     925
# Name: count, dtype: int64
# -------------------------------------
#   # 5 Experience
# loan_status
# 0    2350
# 1     650
# Name: count, dtype: int64
# -------------------------------------
#   # 4 Experience
# loan_status
# 0    2784
# 1     740
# Name: count, dtype: int64
# -------------------------------------
#   # 2 Experience
# loan_status
# 0    3210
# 1     924
# Name: count, dtype: int64
# -------------------------------------
#   # 7 Experience
# loan_status
# 0    1734
# 1     470
# Name: count, dtype: int64
# -------------------------------------
#   # 6 Experience
# loan_status
# 0    2128
# 1     589
# Name: count, dtype: int64
# -------------------------------------
# ...

# %%
sns.histplot(df['person_emp_exp'])
# Out:
# <Axes: xlabel='person_emp_exp', ylabel='Count'>

# %% [markdown]
# # **person_home_ownership

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71900
# 1              21        female      High School          12200
# 2              25        female      High School          12400
# 3              23        female         Bachelor          79700
# 4              24          male           Master          66100
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47900
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56900
# 44998          29          male         Bachelor          33100
# 44999          24          male      High School          51600
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df['person_home_ownership'].value_counts()
# Out:
# person_home_ownership
# RENT        23438
# MORTGAGE    18478
# OWN          2951
# OTHER         117
# Name: count, dtype: int64

# %%
sns.histplot(df['person_home_ownership'])
# Out:
# <Axes: xlabel='person_home_ownership', ylabel='Count'>

# %%
df['Ownership'] = le.fit_transform(df['person_home_ownership'])
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\542553304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ownership'] = le.fit_transform(df['person_home_ownership'])

# %% [markdown]
# # ** loan_amnt

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71900
# 1              21        female      High School          12200
# 2              25        female      High School          12400
# 3              23        female         Bachelor          79700
# 4              24          male           Master          66100
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47900
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56900
# 44998          29          male         Bachelor          33100
# 44999          24          male      High School          51600
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df['loan_amnt'] = df['loan_amnt'].astype(int)
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\268959699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['loan_amnt'] = df['loan_amnt'].astype(int)

# %%
df['loan_amnt'] = df['loan_amnt'].apply(lambda x:(x//100)*100)
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\3655537521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['loan_amnt'] = df['loan_amnt'].apply(lambda x:(x//100)*100)

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71900
# 1              21        female      High School          12200
# 2              25        female      High School          12400
# 3              23        female         Bachelor          79700
# 4              24          male           Master          66100
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47900
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56900
# 44998          29          male         Bachelor          33100
# 44999          24          male      High School          51600
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT      35000           PERSONAL
# ...

# %% [markdown]
# # **loan_intent

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71900
# 1              21        female      High School          12200
# 2              25        female      High School          12400
# 3              23        female         Bachelor          79700
# 4              24          male           Master          66100
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47900
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56900
# 44998          29          male         Bachelor          33100
# 44999          24          male      High School          51600
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT      35000           PERSONAL
# ...

# %%
df['loan_intent'].value_counts()
# Out:
# loan_intent
# EDUCATION            9150
# MEDICAL              8546
# VENTURE              7811
# PERSONAL             7550
# DEBTCONSOLIDATION    7144
# HOMEIMPROVEMENT      4783
# Name: count, dtype: int64

# %%
for i in df['loan_intent'].unique():
    print(i)
    print(df[df['loan_intent'] == i]['loan_status'].value_counts())
    print('-------------------------------------')
# Out:
# PERSONAL
# loan_status
# 0    6029
# 1    1521
# Name: count, dtype: int64
# -------------------------------------
# EDUCATION
# loan_status
# 0    7598
# 1    1552
# Name: count, dtype: int64
# -------------------------------------
# MEDICAL
# loan_status
# 0    6168
# 1    2378
# Name: count, dtype: int64
# -------------------------------------
# VENTURE
# loan_status
# 0    6683
# 1    1128
# Name: count, dtype: int64
# -------------------------------------
# HOMEIMPROVEMENT
# loan_status
# 0    3525
# 1    1258
# Name: count, dtype: int64
# -------------------------------------
# DEBTCONSOLIDATION
# loan_status
# 0    4981
# 1    2163
# Name: count, dtype: int64
# -------------------------------------

# %%
sns.histplot(df['loan_intent'])
plt.xticks(rotation=45)  # Better readability if too many categories
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'PERSONAL'),
#   Text(1, 0, 'EDUCATION'),
#   Text(2, 0, 'MEDICAL'),
#   Text(3, 0, 'VENTURE'),
#   Text(4, 0, 'HOMEIMPROVEMENT'),
#   Text(5, 0, 'DEBTCONSOLIDATION')])

# %%
df['Loan_intent'] = le.fit_transform(df['loan_intent'])
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\1116068827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Loan_intent'] = le.fit_transform(df['loan_intent'])

# %% [markdown]
# # **loan_int_rate

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71900
# 1              21        female      High School          12200
# 2              25        female      High School          12400
# 3              23        female         Bachelor          79700
# 4              24          male           Master          66100
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47900
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56900
# 44998          29          male         Bachelor          33100
# 44999          24          male      High School          51600
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT      35000           PERSONAL
# ...

# %%
df['loan_int_rate'] = df['loan_int_rate'].astype(int)
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\1790150303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['loan_int_rate'] = df['loan_int_rate'].astype(int)

# %%
sns.histplot(df['loan_int_rate'], bins=10)
# Out:
# <Axes: xlabel='loan_int_rate', ylabel='Count'>

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71900
# 1              21        female      High School          12200
# 2              25        female      High School          12400
# 3              23        female         Bachelor          79700
# 4              24          male           Master          66100
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47900
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56900
# 44998          29          male         Bachelor          33100
# 44999          24          male      High School          51600
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT      35000           PERSONAL
# ...

# %%
sns.histplot(df['loan_percent_income'])
# Out:
# <Axes: xlabel='loan_percent_income', ylabel='Count'>

# %%
df['loan_percent_income'].value_counts()
# Out:
# loan_percent_income
# 0.08    2593
# 0.10    2421
# 0.07    2415
# 0.09    2295
# 0.06    2242
#         ...
# 0.57       1
# 0.66       1
# 0.58       1
# 0.63       1
# 0.59       1
# Name: count, Length: 64, dtype: int64

# %%
df['loan_percent_income'].describe()
# Out:
# count    44984.000000
# mean         0.139764
# std          0.087194
# min          0.000000
# 25%          0.070000
# 50%          0.120000
# 75%          0.190000
# max          0.660000
# Name: loan_percent_income, dtype: float64

# %%
df['loan_percent_income'] = df['loan_percent_income'].apply(lambda x:x*100).astype(int)
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\11022214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['loan_percent_income'] = df['loan_percent_income'].apply(lambda x:x*100).astype(int)

# %% [markdown]
# # **cb_person_cred_hist_length

# %%
df['cb_person_cred_hist_length'] = df['cb_person_cred_hist_length'].astype(int)
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\3904077106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cb_person_cred_hist_length'] = df['cb_person_cred_hist_length'].astype(int)

# %%
df['cb_person_cred_hist_length'].describe()
# Out:
# count    44984.000000
# mean         5.864041
# std          3.872965
# min          2.000000
# 25%          3.000000
# 50%          4.000000
# 75%          8.000000
# max         30.000000
# Name: cb_person_cred_hist_length, dtype: float64

# %%
df['cb_person_cred_hist_length']
# Out:
# 0         3
# 1         2
# 2         3
# 3         2
# 4         4
#          ..
# 44995     3
# 44996    11
# 44997    10
# 44998     6
# 44999     3
# Name: cb_person_cred_hist_length, Length: 44984, dtype: int32

# %% [markdown]
# # **previous_loan_defaults_on_file

# %%
df['previous_loan_defaults_on_file']
# Out:
# 0         No
# 1        Yes
# 2         No
# 3         No
# 4         No
#         ...
# 44995     No
# 44996     No
# 44997     No
# 44998     No
# 44999     No
# Name: previous_loan_defaults_on_file, Length: 44984, dtype: object

# %%
df['Previous_loan_defaults_on_file'] = le.fit_transform(df['previous_loan_defaults_on_file'])
# Out:
# C:\Users\tally\AppData\Local\Temp\ipykernel_7308\3807824926.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Previous_loan_defaults_on_file'] = le.fit_transform(df['previous_loan_defaults_on_file'])

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71900
# 1              21        female      High School          12200
# 2              25        female      High School          12400
# 3              23        female         Bachelor          79700
# 4              24          male           Master          66100
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47900
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56900
# 44998          29          male         Bachelor          33100
# 44999          24          male      High School          51600
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT      35000           PERSONAL
# ...

# %%
new_df = df[['person_age','person_income','person_emp_exp','loan_amnt','loan_int_rate','loan_percent_income','cb_person_cred_hist_length','credit_score','gender','Education','Ownership','Loan_intent','Previous_loan_defaults_on_file','loan_status']]

# %%
new_df
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0              22          71900               0      35000             16
# 1              21          12200               0       1000             11
# 2              25          12400               3       5500             12
# 3              23          79700               0      35000             15
# 4              24          66100               1      35000             14
# ...           ...            ...             ...        ...            ...
# 44995          27          47900               6      15000             15
# 44996          37          65800              17       9000             14
# 44997          33          56900               7       2700             10
# 44998          29          33100               4      12000             13
# 44999          24          51600               1       6600             17
#
# ...

# %% [markdown]
# # MODEL BUILDING

# %%
from sklearn.model_selection import train_test_split

# %%
y = new_df['loan_status']

# %%
x = new_df.drop(columns = ['loan_status'])

# %%
x
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0              22          71900               0      35000             16
# 1              21          12200               0       1000             11
# 2              25          12400               3       5500             12
# 3              23          79700               0      35000             15
# 4              24          66100               1      35000             14
# ...           ...            ...             ...        ...            ...
# 44995          27          47900               6      15000             15
# 44996          37          65800              17       9000             14
# 44997          33          56900               7       2700             10
# 44998          29          33100               4      12000             13
# 44999          24          51600               1       6600             17
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=42)

# %%
y_train
# Out:
# 1147     0
# 24831    1
# 2324     0
# 44004    1
# 15026    0
#         ..
# 11288    0
# 44748    1
# 38173    0
# 864      0
# 15799    0
# Name: loan_status, Length: 31488, dtype: int64

# %%
X_train
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 1147           25          87400               3      17000              7
# 24831          27          73300               5       3000             10
# 2324           22          38600               0       8000              6
# 44004          23          36800               2       5000              9
# 15026          24          30900               1       1600             12
# ...           ...            ...             ...        ...            ...
# 11288          22          88400               0       7000             10
# 44748          24          42300               0       5000             16
# 38173          25          79000               3      10000             10
# 864            26         202300               2      20000             11
# 15799          24         210900               3       8000             11
#
# ...

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report

# %%
# Define XGBoost model with hyperparameters
model = XGBClassifier(
    n_estimators=100,  # Number of boosting rounds
    max_depth=3,       # Tree depth
    learning_rate=0.1, # Step size shrinkage
    subsample=0.8,     # Fraction of samples used per tree
    colsample_bytree=0.8,  # Fraction of features used per tree
    random_state=42,
    eval_metric='logloss'  # For binary classification
)

# %%
# Stratified K-Fold ensures balanced class distribution in splits
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

cv_scores = cross_val_score(
    model,
    X_train,
    y_train,
    cv=skf,
    scoring='accuracy'
)

print(f"Stratified CV Accuracy: {np.mean(cv_scores):.4f}")
# Out:
# Stratified CV Accuracy: 0.9207

# %%
# Fit the model on the entire dataset
model.fit(X_train, y_train)

# Make predictions (example)
y_pred = model.predict(X_test)

# Evaluate performance
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     10494
#            1       0.87      0.76      0.81      3002
#
#     accuracy                           0.92     13496
#    macro avg       0.90      0.86      0.88     13496
# weighted avg       0.92      0.92      0.92     13496
